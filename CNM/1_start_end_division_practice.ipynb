# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjing2/SJ_practice/blob/master/CNM/1_start_end_division_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/gdrive/My Drive/인스타그램_프로파일링/Relation(start, end)/cc_2.csv")

# %%
df
# Out:
#              start          end
# 0      13580068590  27733156208
# 1      13337514500  27733156208
# 2      27961899505  27733156208
# 3       5772973535  27733156208
# 4      27733156208  13580068590
# ...            ...          ...
# 10530   3188424467   5557754898
# 10531   3188424467   5763414441
# 10532   3188424467  31450672398
# 10533   3188424467   3685838615
# 10534   3188424467   1435555268
#
# [10535 rows x 2 columns]

# %%
start = df['start']

# %%
start
# Out:
# 0        13580068590
# 1        13337514500
# 2        27961899505
# 3         5772973535
# 4        27733156208
#             ...
# 10530     3188424467
# 10531     3188424467
# 10532     3188424467
# 10533     3188424467
# 10534     3188424467
# Name: start, Length: 10535, dtype: int64

# %%
a = str(start[0]) + ","
a
# Out:
# '13580068590,'

# %%
start_1 = []

for i in range(10535):
    c = str(start[i]) + ","
    start_1.append(str(c))

start_1
# Out:
# ['13580068590,',
#  '13337514500,',
#  '27961899505,',
#  '5772973535,',
#  '27733156208,',
#  '36669978407,',
#  '33249799711,',
#  '13580068590,',
#  '27733156208,',
#  '27733156208,',
#  '40384414061,',
#  '5634736653,',
#  '2213239926,',
#  '40817735077,',
#  '27733156208,',
#  '31075843149,',
#  '11793342881,',
#  '5634736653,',
#  '9198333447,',
#  '3180255400,',
#  '40817735077,',
#  '27733156208,',
#  '7235829698,',
#  '3180255400,',
#  '2592111299,',
#  '3608161032,',
#  '13580068590,',
#  '40817735077,',
#  '27733156208,',
#  '7479640251,',
#  '5816850460,',
#  '7479640251,',
#  '37826567075,',
#  '40817735077,',
#  '19734924165,',
#  '2592111299,',
#  '7546113177,',
#  '4054997077,',
#  '2983112233,',
#  '27733156208,',
#  '40384414061,',
#  '7546113177,',
#  '13580068590,',
#  '40384414061,',
#  '37826567075,',
#  '37826567075,',
#  '40384414061,',
#  '40384414061,',
#  '37826567075,',
#  '40384414061,',
#  '40384414061,',
#  '40384414061,',
#  '40384414061,',
# ...

# %%
start_df = pd.DataFrame({"start_1":start_1})

# %%
start_df
# Out:
#             start_1
# 0      13580068590,
# 1      13337514500,
# 2      27961899505,
# 3       5772973535,
# 4      27733156208,
# ...             ...
# 10530   3188424467,
# 10531   3188424467,
# 10532   3188424467,
# 10533   3188424467,
# 10534   3188424467,
#
# [10535 rows x 1 columns]

# %%
start_df["start_1"]
# Out:
# 0        13580068590,
# 1        13337514500,
# 2        27961899505,
# 3         5772973535,
# 4        27733156208,
#              ...
# 10530     3188424467,
# 10531     3188424467,
# 10532     3188424467,
# 10533     3188424467,
# 10534     3188424467,
# Name: start_1, Length: 10535, dtype: object

# %%
start_df.to_csv("/content/gdrive/My Drive/프로젝트/network/start_df.csv")

# %%
df.to_csv("/content/gdrive/My Drive/프로젝트/network/cc_2_df.csv")
