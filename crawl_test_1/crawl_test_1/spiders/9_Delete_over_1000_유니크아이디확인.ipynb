# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjing2/SJ_practice/blob/master/crawl_test_1/crawl_test_1/spiders/9_Delete_over_1000_%EC%9C%A0%EB%8B%88%ED%81%AC%EC%95%84%EC%9D%B4%EB%94%94%ED%99%95%EC%9D%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/gdrive/My Drive/인스타그램_프로파일링/Post/Delete(foreign, over1000)/cc_delete_over_1000.csv', index_col =[0])

# %%
df
# Out:
#          insta_id  ...                                          next_page
# 0       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# 1       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# 2       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# 3       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# 4       jjjjy_o.o  ...  https://www.instagram.com/graphql/query/?query...
# ...           ...  ...                                                ...
# 32825  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
# 32826  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
# 32827  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
# 32828  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
# 32829  heeboulder  ...  https://www.instagram.com/graphql/query/?query...
#
# [32830 rows x 13 columns]

# %%
a = df['insta_id']
a
# Out:
# 0         jjjjy_o.o
# 1         jjjjy_o.o
# 2         jjjjy_o.o
# 3         jjjjy_o.o
# 4         jjjjy_o.o
#             ...
# 32825    heeboulder
# 32826    heeboulder
# 32827    heeboulder
# 32828    heeboulder
# 32829    heeboulder
# Name: insta_id, Length: 32830, dtype: object

# %%
b = pd.unique(a)
b
# Out:
# array(['jjjjy_o.o', 'r_miyaaa', 'dmdmdmd_ec', ..., 'palette_room_daegu',
#        'remaxcentral.official', 'heeboulder'], dtype=object)

# %%
len(b)
# Out:
# 1561

# %%
c = df['inner_id']
c
# Out:
# 0            1582899
# 1            1582899
# 2            1582899
# 3            1582899
# 4            1582899
#             ...
# 32825    39901859586
# 32826    39901859586
# 32827    39901859586
# 32828    39901859586
# 32829    39901859586
# Name: inner_id, Length: 32830, dtype: int64

# %%
d = pd.unique(c)
d
# Out:
# array([    1582899,     2797872,     2648672, ..., 39521089229,
#        39718579061, 39901859586])

# %%
len(d)
# Out:
# 1561
