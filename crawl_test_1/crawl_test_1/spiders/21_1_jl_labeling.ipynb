# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjing2/SJ_practice/blob/master/crawl_test_1/crawl_test_1/spiders/21_1_jl_labeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
import pandas as pd
import numpy as np
from IPython.display import clear_output

# %%
df = pd.read_csv('/content/gdrive/My Drive/프로젝트/jl_id_region_1.csv')

# %%
def label(df, start_idx=0):
    for x in range(start_idx, len(df)):
        print('현재 지역 라벨: ', df.loc[x][0])
        print([location for location in df.loc[x] if type(location)==str][1:])
        region_label = input('사용자의 지역을 숫자로 입력해 주세요(종료를 원하시면 0을 입력해 주세요)\n수도권(1), 강원(2), 충청(3), 전라(4), 경상(5), 모름(6) ')
        if region_label == '0':
            print('종료 인덱스: ', x)
            break
        df['region'][x] = region_label
        clear_output()
        if x == len(df)-1:
            print('더 이상 라벨링할 데이터가 없습니다!')

# %%
# (데이터프레임, 라벨링 시작하고 싶은 인덱스)를 함수에 넣어서 실행
label(df, 0)

# %%
df[0:116]
# Out:
#      region      insta_id  ...  698  699
# 0       NaN   0.0hwan_eee  ...  NaN  NaN
# 1       NaN      06su8227  ...  NaN  NaN
# 2       NaN       080mini  ...  NaN  NaN
# 3       NaN  0dbqslapfhd0  ...  NaN  NaN
# 4       NaN   0meeee___97  ...  NaN  NaN
# ..      ...           ...  ...  ...  ...
# 111     NaN  aroristagram  ...  NaN  NaN
# 112     NaN  arri_actress  ...  NaN  NaN
# 113     NaN     ashelisly  ...  NaN  NaN
# 114     NaN     asksmssks  ...  NaN  NaN
# 115     NaN       asm9339  ...  NaN  NaN
#
# [116 rows x 702 columns]

# %%
# df.to_csv('/content/gdrive/My Drive/프로젝트/라벨링/cc_labeling_113.csv', index=False)
